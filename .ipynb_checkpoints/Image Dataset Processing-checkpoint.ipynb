# %% [markdown]
# # Cropping and Resizing Images in 4-class Images Dataset

# %% [markdown]
# ## Imports

# %%
import os
import xml.etree.ElementTree as ET
from skimage import io
from skimage.transform import resize
import glob
from pathlib import Path
import numpy as np

# %% [markdown]
# ## Get Bounding Boxes

# %%
def get_bounding_boxes(annot):
    tree = ET.parse(annot)
    root = tree.getroot()
    objects = root.findall('object')
    bbox = []
    for o in objects:
        bndbox = o.find('bndbox')
        xmin = int(bndbox.find('xmin').text)
        ymin = int(bndbox.find('ymin').text)
        xmax = int(bndbox.find('xmax').text)
        ymax = int(bndbox.find('ymax').text)
        bbox.append((xmin, ymin, xmax, ymax))
    return bbox

# %% [markdown]
# ## Crop and Resize

# %%
def process_image(image_file, bounding_boxes, output_folder):
    image = io.imread(image_file)
    image_size=(128, 128)

    cropped_image_list = []
    
    for i, bbox in enumerate(bounding_boxes):
        xmin, ymin, xmax, ymax = bbox
        cropped_image = image[ymin:ymax, xmin:xmax]
        resized_image = resize(cropped_image, image_size)
        
        resized_image_uint8 = (resized_image * 255).astype(np.uint8)
        
        output_path = os.path.join(output_folder, f"cropped_{i}_{os.path.basename(image_file)}")
        Path(output_folder).mkdir(parents=True, exist_ok=True)
        io.imsave(output_path, resized_image_uint8)
        cropped_image_list.append(output_path)

    return cropped_image_list

# %% [markdown]
# ## Folders Settings

# %%
image_folder = './data/Images/*/*'
annotation_folder = './data/Annotations/*/*'
output_folder = './data/Cropped Images'

image_files = glob.glob(image_folder)
annotation_files = glob.glob(annotation_folder)

# %% [markdown]
# ## Run

# %%
annotations = {os.path.splitext(os.path.basename(f))[0]: f for f in annotation_files}

for image_file in image_files:
    image_code_name = os.path.splitext(os.path.basename(image_file))[0]
    annotation_file = annotations.get(image_code_name)
    
    if annotation_file:
        bbox = get_bounding_boxes(annotation_file)
        breed_folder = os.path.basename(os.path.dirname(image_file))
        breed_output_folder = os.path.join(output_folder, breed_folder)     
        cropped_images = process_image(image_file, bbox, breed_output_folder)
        print(f"Processed {image_file}, saved cropped images: {cropped_images}")
    else:
        print(f"No annotation found for {image_file}")
# Out:
# Processed ./data/Images/n02105505-komondor/n02105505_4325.jpg, saved cropped images: ['./data/Cropped Images/n02105505-komondor/cropped_0_n02105505_4325.jpg']
# Processed ./data/Images/n02105505-komondor/n02105505_43.jpg, saved cropped images: ['./data/Cropped Images/n02105505-komondor/cropped_0_n02105505_43.jpg']
# Processed ./data/Images/n02105505-komondor/n02105505_1077.jpg, saved cropped images: ['./data/Cropped Images/n02105505-komondor/cropped_0_n02105505_1077.jpg']
# Processed ./data/Images/n02105505-komondor/n02105505_3933.jpg, saved cropped images: ['./data/Cropped Images/n02105505-komondor/cropped_0_n02105505_3933.jpg']
# Processed ./data/Images/n02105505-komondor/n02105505_4090.jpg, saved cropped images: ['./data/Cropped Images/n02105505-komondor/cropped_0_n02105505_4090.jpg']
# Processed ./data/Images/n02105505-komondor/n02105505_317.jpg, saved cropped images: ['./data/Cropped Images/n02105505-komondor/cropped_0_n02105505_317.jpg']
# Processed ./data/Images/n02105505-komondor/n02105505_935.jpg, saved cropped images: ['./data/Cropped Images/n02105505-komondor/cropped_0_n02105505_935.jpg']
# Processed ./data/Images/n02105505-komondor/n02105505_3887.jpg, saved cropped images: ['./data/Cropped Images/n02105505-komondor/cropped_0_n02105505_3887.jpg']
# Processed ./data/Images/n02105505-komondor/n02105505_4118.jpg, saved cropped images: ['./data/Cropped Images/n02105505-komondor/cropped_0_n02105505_4118.jpg']
# Processed ./data/Images/n02105505-komondor/n02105505_2178.jpg, saved cropped images: ['./data/Cropped Images/n02105505-komondor/cropped_0_n02105505_2178.jpg']
# Processed ./data/Images/n02105505-komondor/n02105505_4290.jpg, saved cropped images: ['./data/Cropped Images/n02105505-komondor/cropped_0_n02105505_4290.jpg']
# Processed ./data/Images/n02105505-komondor/n02105505_3716.jpg, saved cropped images: ['./data/Cropped Images/n02105505-komondor/cropped_0_n02105505_3716.jpg']
# Processed ./data/Images/n02105505-komondor/n02105505_2420.jpg, saved cropped images: ['./data/Cropped Images/n02105505-komondor/cropped_0_n02105505_2420.jpg']
# Processed ./data/Images/n02105505-komondor/n02105505_3672.jpg, saved cropped images: ['./data/Cropped Images/n02105505-komondor/cropped_0_n02105505_3672.jpg']
# Processed ./data/Images/n02105505-komondor/n02105505_4069.jpg, saved cropped images: ['./data/Cropped Images/n02105505-komondor/cropped_0_n02105505_4069.jpg']
# Processed ./data/Images/n02105505-komondor/n02105505_3706.jpg, saved cropped images: ['./data/Cropped Images/n02105505-komondor/cropped_0_n02105505_3706.jpg']
# Processed ./data/Images/n02105505-komondor/n02105505_2155.jpg, saved cropped images: ['./data/Cropped Images/n02105505-komondor/cropped_0_n02105505_2155.jpg']
# Processed ./data/Images/n02105505-komondor/n02105505_4256.jpg, saved cropped images: ['./data/Cropped Images/n02105505-komondor/cropped_0_n02105505_4256.jpg']
# Processed ./data/Images/n02105505-komondor/n02105505_1312.jpg, saved cropped images: ['./data/Cropped Images/n02105505-komondor/cropped_0_n02105505_1312.jpg']
# Processed ./data/Images/n02105505-komondor/n02105505_853.jpg, saved cropped images: ['./data/Cropped Images/n02105505-komondor/cropped_0_n02105505_853.jpg']
# Processed ./data/Images/n02105505-komondor/n02105505_3713.jpg, saved cropped images: ['./data/Cropped Images/n02105505-komondor/cropped_0_n02105505_3713.jpg']
# Processed ./data/Images/n02105505-komondor/n02105505_3698.jpg, saved cropped images: ['./data/Cropped Images/n02105505-komondor/cropped_0_n02105505_3698.jpg']
# Processed ./data/Images/n02105505-komondor/n02105505_2592.jpg, saved cropped images: ['./data/Cropped Images/n02105505-komondor/cropped_0_n02105505_2592.jpg']
# Processed ./data/Images/n02105505-komondor/n02105505_1272.jpg, saved cropped images: ['./data/Cropped Images/n02105505-komondor/cropped_0_n02105505_1272.jpg']
# Processed ./data/Images/n02105505-komondor/n02105505_2037.jpg, saved cropped images: ['./data/Cropped Images/n02105505-komondor/cropped_0_n02105505_2037.jpg']
# Processed ./data/Images/n02105505-komondor/n02105505_4081.jpg, saved cropped images: ['./data/Cropped Images/n02105505-komondor/cropped_0_n02105505_4081.jpg', './data/Cropped Images/n02105505-komondor/cropped_1_n02105505_4081.jpg', './data/Cropped Images/n02105505-komondor/cropped_2_n02105505_4081.jpg']
# Processed ./data/Images/n02105505-komondor/n02105505_2382.jpg, saved cropped images: ['./data/Cropped Images/n02105505-komondor/cropped_0_n02105505_2382.jpg']
# Processed ./data/Images/n02105505-komondor/n02105505_3705.jpg, saved cropped images: ['./data/Cropped Images/n02105505-komondor/cropped_0_n02105505_3705.jpg']
# Processed ./data/Images/n02105505-komondor/n02105505_2156.jpg, saved cropped images: ['./data/Cropped Images/n02105505-komondor/cropped_0_n02105505_2156.jpg']
# Processed ./data/Images/n02105505-komondor/n02105505_4282.jpg, saved cropped images: ['./data/Cropped Images/n02105505-komondor/cropped_0_n02105505_4282.jpg']
# Processed ./data/Images/n02105505-komondor/n02105505_2426.jpg, saved cropped images: ['./data/Cropped Images/n02105505-komondor/cropped_0_n02105505_2426.jpg']
# Processed ./data/Images/n02105505-komondor/n02105505_475.jpg, saved cropped images: ['./data/Cropped Images/n02105505-komondor/cropped_0_n02105505_475.jpg']
# Processed ./data/Images/n02105505-komondor/n02105505_3738.jpg, saved cropped images: ['./data/Cropped Images/n02105505-komondor/cropped_0_n02105505_3738.jpg']
# Processed ./data/Images/n02105505-komondor/n02105505_515.jpg, saved cropped images: ['./data/Cropped Images/n02105505-komondor/cropped_0_n02105505_515.jpg']
# Processed ./data/Images/n02105505-komondor/n02105505_3328.jpg, saved cropped images: ['./data/Cropped Images/n02105505-komondor/cropped_0_n02105505_3328.jpg']
# Processed ./data/Images/n02105505-komondor/n02105505_572.jpg, saved cropped images: ['./data/Cropped Images/n02105505-komondor/cropped_0_n02105505_572.jpg']
# Processed ./data/Images/n02105505-komondor/n02105505_3603.jpg, saved cropped images: ['./data/Cropped Images/n02105505-komondor/cropped_0_n02105505_3603.jpg']
# Processed ./data/Images/n02105505-komondor/n02105505_3617.jpg, saved cropped images: ['./data/Cropped Images/n02105505-komondor/cropped_0_n02105505_3617.jpg']
# Processed ./data/Images/n02105505-komondor/n02105505_1148.jpg, saved cropped images: ['./data/Cropped Images/n02105505-komondor/cropped_0_n02105505_1148.jpg']
# Processed ./data/Images/n02105505-komondor/n02105505_4031.jpg, saved cropped images: ['./data/Cropped Images/n02105505-komondor/cropped_0_n02105505_4031.jpg']
# Processed ./data/Images/n02105505-komondor/n02105505_4186.jpg, saved cropped images: ['./data/Cropped Images/n02105505-komondor/cropped_0_n02105505_4186.jpg']
# Processed ./data/Images/n02105505-komondor/n02105505_4353.jpg, saved cropped images: ['./data/Cropped Images/n02105505-komondor/cropped_0_n02105505_4353.jpg']
# Processed ./data/Images/n02105505-komondor/n02105505_4435.jpg, saved cropped images: ['./data/Cropped Images/n02105505-komondor/cropped_0_n02105505_4435.jpg']
# Processed ./data/Images/n02105505-komondor/n02105505_4351.jpg, saved cropped images: ['./data/Cropped Images/n02105505-komondor/cropped_0_n02105505_4351.jpg']
# Processed ./data/Images/n02105505-komondor/n02105505_3833.jpg, saved cropped images: ['./data/Cropped Images/n02105505-komondor/cropped_0_n02105505_3833.jpg']
# Processed ./data/Images/n02105505-komondor/n02105505_2873.jpg, saved cropped images: ['./data/Cropped Images/n02105505-komondor/cropped_0_n02105505_2873.jpg']
# Processed ./data/Images/n02105505-komondor/n02105505_3576.jpg, saved cropped images: ['./data/Cropped Images/n02105505-komondor/cropped_0_n02105505_3576.jpg']
# Processed ./data/Images/n02105505-komondor/n02105505_1406.jpg, saved cropped images: ['./data/Cropped Images/n02105505-komondor/cropped_0_n02105505_1406.jpg']
# Processed ./data/Images/n02105505-komondor/n02105505_1360.jpg, saved cropped images: ['./data/Cropped Images/n02105505-komondor/cropped_0_n02105505_1360.jpg']
# Processed ./data/Images/n02105505-komondor/n02105505_2872.jpg, saved cropped images: ['./data/Cropped Images/n02105505-komondor/cropped_0_n02105505_2872.jpg']
# Processed ./data/Images/n02105505-komondor/n02105505_4436.jpg, saved cropped images: ['./data/Cropped Images/n02105505-komondor/cropped_0_n02105505_4436.jpg', './data/Cropped Images/n02105505-komondor/cropped_1_n02105505_4436.jpg']
# Processed ./data/Images/n02105505-komondor/n02105505_955.jpg, saved cropped images: ['./data/Cropped Images/n02105505-komondor/cropped_0_n02105505_955.jpg']
# Processed ./data/Images/n02105505-komondor/n02105505_4383.jpg, saved cropped images: ['./data/Cropped Images/n02105505-komondor/cropped_0_n02105505_4383.jpg']
# Processed ./data/Images/n02105505-komondor/n02105505_2043.jpg, saved cropped images: ['./data/Cropped Images/n02105505-komondor/cropped_0_n02105505_2043.jpg']
# Processed ./data/Images/n02105505-komondor/n02105505_32.jpg, saved cropped images: ['./data/Cropped Images/n02105505-komondor/cropped_0_n02105505_32.jpg']
# Processed ./data/Images/n02105505-komondor/n02105505_3002.jpg, saved cropped images: ['./data/Cropped Images/n02105505-komondor/cropped_0_n02105505_3002.jpg']
# Processed ./data/Images/n02105505-komondor/n02105505_3957.jpg, saved cropped images: ['./data/Cropped Images/n02105505-komondor/cropped_0_n02105505_3957.jpg']
# Processed ./data/Images/n02105505-komondor/n02105505_4143.jpg, saved cropped images: ['./data/Cropped Images/n02105505-komondor/cropped_0_n02105505_4143.jpg']
# Processed ./data/Images/n02105505-komondor/n02105505_561.jpg, saved cropped images: ['./data/Cropped Images/n02105505-komondor/cropped_0_n02105505_561.jpg']
# Processed ./data/Images/n02105505-komondor/n02105505_4180.jpg, saved cropped images: ['./data/Cropped Images/n02105505-komondor/cropped_0_n02105505_4180.jpg']
# Processed ./data/Images/n02105505-komondor/n02105505_4382.jpg, saved cropped images: ['./data/Cropped Images/n02105505-komondor/cropped_0_n02105505_4382.jpg']
# Processed ./data/Images/n02105505-komondor/n02105505_2083.jpg, saved cropped images: ['./data/Cropped Images/n02105505-komondor/cropped_0_n02105505_2083.jpg']
# Processed ./data/Images/n02105505-komondor/n02105505_4394.jpg, saved cropped images: ['./data/Cropped Images/n02105505-komondor/cropped_0_n02105505_4394.jpg']
# Processed ./data/Images/n02105505-komondor/n02105505_3389.jpg, saved cropped images: ['./data/Cropped Images/n02105505-komondor/cropped_0_n02105505_3389.jpg']
# Processed ./data/Images/n02105505-komondor/n02105505_2281.jpg, saved cropped images: ['./data/Cropped Images/n02105505-komondor/cropped_0_n02105505_2281.jpg']
# Processed ./data/Images/n02105505-komondor/n02105505_3766.jpg, saved cropped images: ['./data/Cropped Images/n02105505-komondor/cropped_0_n02105505_3766.jpg']
# Processed ./data/Images/n02105505-komondor/n02105505_4021.jpg, saved cropped images: ['./data/Cropped Images/n02105505-komondor/cropped_0_n02105505_4021.jpg']
# Processed ./data/Images/n02105505-komondor/n02105505_1159.jpg, saved cropped images: ['./data/Cropped Images/n02105505-komondor/cropped_0_n02105505_1159.jpg']
# Processed ./data/Images/n02105505-komondor/n02105505_2322.jpg, saved cropped images: ['./data/Cropped Images/n02105505-komondor/cropped_0_n02105505_2322.jpg']
# Processed ./data/Images/n02105505-komondor/n02105505_3982.jpg, saved cropped images: ['./data/Cropped Images/n02105505-komondor/cropped_0_n02105505_3982.jpg']
# Processed ./data/Images/n02105505-komondor/n02105505_2685.jpg, saved cropped images: ['./data/Cropped Images/n02105505-komondor/cropped_0_n02105505_2685.jpg', './data/Cropped Images/n02105505-komondor/cropped_1_n02105505_2685.jpg', './data/Cropped Images/n02105505-komondor/cropped_2_n02105505_2685.jpg']
# Processed ./data/Images/n02105505-komondor/n02105505_3564.jpg, saved cropped images: ['./data/Cropped Images/n02105505-komondor/cropped_0_n02105505_3564.jpg']
# Processed ./data/Images/n02105505-komondor/n02105505_2134.jpg, saved cropped images: ['./data/Cropped Images/n02105505-komondor/cropped_0_n02105505_2134.jpg']
# Processed ./data/Images/n02105505-komondor/n02105505_3558.jpg, saved cropped images: ['./data/Cropped Images/n02105505-komondor/cropped_0_n02105505_3558.jpg']
# Processed ./data/Images/n02105505-komondor/n02105505_358.jpg, saved cropped images: ['./data/Cropped Images/n02105505-komondor/cropped_0_n02105505_358.jpg']
# Processed ./data/Images/n02105505-komondor/n02105505_2069.jpg, saved cropped images: ['./data/Cropped Images/n02105505-komondor/cropped_0_n02105505_2069.jpg']
# Processed ./data/Images/n02105505-komondor/n02105505_4398.jpg, saved cropped images: ['./data/Cropped Images/n02105505-komondor/cropped_0_n02105505_4398.jpg']
# Processed ./data/Images/n02105505-komondor/n02105505_3805.jpg, saved cropped images: ['./data/Cropped Images/n02105505-komondor/cropped_0_n02105505_3805.jpg']
# Processed ./data/Images/n02105505-komondor/n02105505_3781.jpg, saved cropped images: ['./data/Cropped Images/n02105505-komondor/cropped_0_n02105505_3781.jpg']
# Processed ./data/Images/n02105505-komondor/n02105505_3030.jpg, saved cropped images: ['./data/Cropped Images/n02105505-komondor/cropped_0_n02105505_3030.jpg']
# Processed ./data/Images/n02105505-komondor/n02105505_2886.jpg, saved cropped images: ['./data/Cropped Images/n02105505-komondor/cropped_0_n02105505_2886.jpg']
# Processed ./data/Images/n02105505-komondor/n02105505_3541.jpg, saved cropped images: ['./data/Cropped Images/n02105505-komondor/cropped_0_n02105505_3541.jpg']
# Processed ./data/Images/n02105505-komondor/n02105505_3409.jpg, saved cropped images: ['./data/Cropped Images/n02105505-komondor/cropped_0_n02105505_3409.jpg']
# Processed ./data/Images/n02105505-komondor/n02105505_3806.jpg, saved cropped images: ['./data/Cropped Images/n02105505-komondor/cropped_0_n02105505_3806.jpg']
# Processed ./data/Images/n02105505-komondor/n02105505_1988.jpg, saved cropped images: ['./data/Cropped Images/n02105505-komondor/cropped_0_n02105505_1988.jpg']
# Processed ./data/Images/n02105505-komondor/n02105505_1383.jpg, saved cropped images: ['./data/Cropped Images/n02105505-komondor/cropped_0_n02105505_1383.jpg']
# Processed ./data/Images/n02105505-komondor/n02105505_1426.jpg, saved cropped images: ['./data/Cropped Images/n02105505-komondor/cropped_0_n02105505_1426.jpg']
# Processed ./data/Images/n02105505-komondor/n02105505_2489.jpg, saved cropped images: ['./data/Cropped Images/n02105505-komondor/cropped_0_n02105505_2489.jpg']
# Processed ./data/Images/n02105505-komondor/n02105505_3967.jpg, saved cropped images: ['./data/Cropped Images/n02105505-komondor/cropped_0_n02105505_3967.jpg']
# Processed ./data/Images/n02105505-komondor/n02105505_2270.jpg, saved cropped images: ['./data/Cropped Images/n02105505-komondor/cropped_0_n02105505_2270.jpg']
# Processed ./data/Images/n02105505-komondor/n02105505_4417.jpg, saved cropped images: ['./data/Cropped Images/n02105505-komondor/cropped_0_n02105505_4417.jpg']
# Processed ./data/Images/n02105505-komondor/n02105505_1225.jpg, saved cropped images: ['./data/Cropped Images/n02105505-komondor/cropped_0_n02105505_1225.jpg']
# Processed ./data/Images/n02105505-komondor/n02105505_3787.jpg, saved cropped images: ['./data/Cropped Images/n02105505-komondor/cropped_0_n02105505_3787.jpg']
# Processed ./data/Images/n02105505-komondor/n02105505_3744.jpg, saved cropped images: ['./data/Cropped Images/n02105505-komondor/cropped_0_n02105505_3744.jpg']
# Processed ./data/Images/n02105505-komondor/n02105505_192.jpg, saved cropped images: ['./data/Cropped Images/n02105505-komondor/cropped_0_n02105505_192.jpg']
# Processed ./data/Images/n02105505-komondor/n02105505_3792.jpg, saved cropped images: ['./data/Cropped Images/n02105505-komondor/cropped_0_n02105505_3792.jpg']
# Processed ./data/Images/n02105505-komondor/n02105505_3380.jpg, saved cropped images: ['./data/Cropped Images/n02105505-komondor/cropped_0_n02105505_3380.jpg']
# Processed ./data/Images/n02105505-komondor/n02105505_1024.jpg, saved cropped images: ['./data/Cropped Images/n02105505-komondor/cropped_0_n02105505_1024.jpg']
# Processed ./data/Images/n02105505-komondor/n02105505_1018.jpg, saved cropped images: ['./data/Cropped Images/n02105505-komondor/cropped_0_n02105505_1018.jpg']
# Processed ./data/Images/n02105505-komondor/n02105505_3784.jpg, saved cropped images: ['./data/Cropped Images/n02105505-komondor/cropped_0_n02105505_3784.jpg']
# Processed ./data/Images/n02105505-komondor/n02105505_4028.jpg, saved cropped images: ['./data/Cropped Images/n02105505-komondor/cropped_0_n02105505_4028.jpg', './data/Cropped Images/n02105505-komondor/cropped_1_n02105505_4028.jpg']
# Processed ./data/Images/n02105505-komondor/n02105505_2465.jpg, saved cropped images: ['./data/Cropped Images/n02105505-komondor/cropped_0_n02105505_2465.jpg']
# Processed ./data/Images/n02105505-komondor/n02105505_2101.jpg, saved cropped images: ['./data/Cropped Images/n02105505-komondor/cropped_0_n02105505_2101.jpg']
# Processed ./data/Images/n02105505-komondor/n02105505_3578.jpg, saved cropped images: ['./data/Cropped Images/n02105505-komondor/cropped_0_n02105505_3578.jpg']
# Processed ./data/Images/n02105505-komondor/n02105505_2699.jpg, saved cropped images: ['./data/Cropped Images/n02105505-komondor/cropped_0_n02105505_2699.jpg']
# Processed ./data/Images/n02105505-komondor/n02105505_3008.jpg, saved cropped images: ['./data/Cropped Images/n02105505-komondor/cropped_0_n02105505_3008.jpg']
# Processed ./data/Images/n02105505-komondor/n02105505_345.jpg, saved cropped images: ['./data/Cropped Images/n02105505-komondor/cropped_0_n02105505_345.jpg']
# Processed ./data/Images/n02105505-komondor/n02105505_2316.jpg, saved cropped images: ['./data/Cropped Images/n02105505-komondor/cropped_0_n02105505_2316.jpg']
# Processed ./data/Images/n02105505-komondor/n02105505_1145.jpg, saved cropped images: ['./data/Cropped Images/n02105505-komondor/cropped_0_n02105505_1145.jpg']
# Processed ./data/Images/n02105505-komondor/n02105505_3356.jpg, saved cropped images: ['./data/Cropped Images/n02105505-komondor/cropped_0_n02105505_3356.jpg']
# Processed ./data/Images/n02105505-komondor/n02105505_1541.jpg, saved cropped images: ['./data/Cropped Images/n02105505-komondor/cropped_0_n02105505_1541.jpg']
# Processed ./data/Images/n02105505-komondor/n02105505_769.jpg, saved cropped images: ['./data/Cropped Images/n02105505-komondor/cropped_0_n02105505_769.jpg']
# Processed ./data/Images/n02105505-komondor/n02105505_4304.jpg, saved cropped images: ['./data/Cropped Images/n02105505-komondor/cropped_0_n02105505_4304.jpg']
# Processed ./data/Images/n02105505-komondor/n02105505_3721.jpg, saved cropped images: ['./data/Cropped Images/n02105505-komondor/cropped_0_n02105505_3721.jpg']
# Processed ./data/Images/n02105505-komondor/n02105505_861.jpg, saved cropped images: ['./data/Cropped Images/n02105505-komondor/cropped_0_n02105505_861.jpg']
# Processed ./data/Images/n02105505-komondor/n02105505_4271.jpg, saved cropped images: ['./data/Cropped Images/n02105505-komondor/cropped_0_n02105505_4271.jpg']
# Processed ./data/Images/n02105505-komondor/n02105505_3091.jpg, saved cropped images: ['./data/Cropped Images/n02105505-komondor/cropped_0_n02105505_3091.jpg']
# Processed ./data/Images/n02105505-komondor/n02105505_3913.jpg, saved cropped images: ['./data/Cropped Images/n02105505-komondor/cropped_0_n02105505_3913.jpg', './data/Cropped Images/n02105505-komondor/cropped_1_n02105505_3913.jpg']
# Processed ./data/Images/n02105505-komondor/n02105505_3132.jpg, saved cropped images: ['./data/Cropped Images/n02105505-komondor/cropped_0_n02105505_3132.jpg']
# Processed ./data/Images/n02105505-komondor/n02105505_3898.jpg, saved cropped images: ['./data/Cropped Images/n02105505-komondor/cropped_0_n02105505_3898.jpg']
# Processed ./data/Images/n02105505-komondor/n02105505_2760.jpg, saved cropped images: ['./data/Cropped Images/n02105505-komondor/cropped_0_n02105505_2760.jpg']
# Processed ./data/Images/n02105505-komondor/n02105505_4311.jpg, saved cropped images: ['./data/Cropped Images/n02105505-komondor/cropped_0_n02105505_4311.jpg']
# Processed ./data/Images/n02105505-komondor/n02105505_914.jpg, saved cropped images: ['./data/Cropped Images/n02105505-komondor/cropped_0_n02105505_914.jpg']
# Processed ./data/Images/n02105505-komondor/n02105505_2992.jpg, saved cropped images: ['./data/Cropped Images/n02105505-komondor/cropped_0_n02105505_2992.jpg']
# Processed ./data/Images/n02105505-komondor/n02105505_296.jpg, saved cropped images: ['./data/Cropped Images/n02105505-komondor/cropped_0_n02105505_296.jpg']
# Processed ./data/Images/n02105505-komondor/n02105505_4105.jpg, saved cropped images: ['./data/Cropped Images/n02105505-komondor/cropped_0_n02105505_4105.jpg']
# Processed ./data/Images/n02105505-komondor/n02105505_2548.jpg, saved cropped images: ['./data/Cropped Images/n02105505-komondor/cropped_0_n02105505_2548.jpg']
# Processed ./data/Images/n02105505-komondor/n02105505_3050.jpg, saved cropped images: ['./data/Cropped Images/n02105505-komondor/cropped_0_n02105505_3050.jpg']
# Processed ./data/Images/n02105505-komondor/n02105505_3723.jpg, saved cropped images: ['./data/Cropped Images/n02105505-komondor/cropped_0_n02105505_3723.jpg']
# Processed ./data/Images/n02105505-komondor/n02105505_4070.jpg, saved cropped images: ['./data/Cropped Images/n02105505-komondor/cropped_0_n02105505_4070.jpg']
# Processed ./data/Images/n02105505-komondor/n02105505_3904.jpg, saved cropped images: ['./data/Cropped Images/n02105505-komondor/cropped_0_n02105505_3904.jpg']
# Processed ./data/Images/n02105505-komondor/n02105505_4138.jpg, saved cropped images: ['./data/Cropped Images/n02105505-komondor/cropped_0_n02105505_4138.jpg']
# Processed ./data/Images/n02105505-komondor/n02105505_4458.jpg, saved cropped images: ['./data/Cropped Images/n02105505-komondor/cropped_0_n02105505_4458.jpg']
# Processed ./data/Images/n02105505-komondor/n02105505_4302.jpg, saved cropped images: ['./data/Cropped Images/n02105505-komondor/cropped_0_n02105505_4302.jpg']
# Processed ./data/Images/n02105505-komondor/n02105505_3647.jpg, saved cropped images: ['./data/Cropped Images/n02105505-komondor/cropped_0_n02105505_3647.jpg', './data/Cropped Images/n02105505-komondor/cropped_1_n02105505_3647.jpg', './data/Cropped Images/n02105505-komondor/cropped_2_n02105505_3647.jpg']
# Processed ./data/Images/n02105505-komondor/n02105505_1657.jpg, saved cropped images: ['./data/Cropped Images/n02105505-komondor/cropped_0_n02105505_1657.jpg']
# Processed ./data/Images/n02105505-komondor/n02105505_4115.jpg, saved cropped images: ['./data/Cropped Images/n02105505-komondor/cropped_0_n02105505_4115.jpg']
# Processed ./data/Images/n02105505-komondor/n02105505_2570.jpg, saved cropped images: ['./data/Cropped Images/n02105505-komondor/cropped_0_n02105505_2570.jpg']
# Processed ./data/Images/n02105505-komondor/n02105505_3652.jpg, saved cropped images: ['./data/Cropped Images/n02105505-komondor/cropped_0_n02105505_3652.jpg']
# Processed ./data/Images/n02105505-komondor/n02105505_3444.jpg, saved cropped images: ['./data/Cropped Images/n02105505-komondor/cropped_0_n02105505_3444.jpg']
# Processed ./data/Images/n02105505-komondor/n02105505_2982.jpg, saved cropped images: ['./data/Cropped Images/n02105505-komondor/cropped_0_n02105505_2982.jpg']
# Processed ./data/Images/n02105505-komondor/n02105505_938.jpg, saved cropped images: ['./data/Cropped Images/n02105505-komondor/cropped_0_n02105505_938.jpg']
# Processed ./data/Images/n02105505-komondor/n02105505_4329.jpg, saved cropped images: ['./data/Cropped Images/n02105505-komondor/cropped_0_n02105505_4329.jpg']
# Processed ./data/Images/n02105505-komondor/n02105505_1090.jpg, saved cropped images: ['./data/Cropped Images/n02105505-komondor/cropped_0_n02105505_1090.jpg']
# Processed ./data/Images/n02105505-komondor/n02105505_3650.jpg, saved cropped images: ['./data/Cropped Images/n02105505-komondor/cropped_0_n02105505_3650.jpg']
# Processed ./data/Images/n02105505-komondor/n02105505_521.jpg, saved cropped images: ['./data/Cropped Images/n02105505-komondor/cropped_0_n02105505_521.jpg']
# Processed ./data/Images/n02105505-komondor/n02105505_441.jpg, saved cropped images: ['./data/Cropped Images/n02105505-komondor/cropped_0_n02105505_441.jpg']
# Processed ./data/Images/n02105505-komondor/n02105505_1443.jpg, saved cropped images: ['./data/Cropped Images/n02105505-komondor/cropped_0_n02105505_1443.jpg']
# Processed ./data/Images/n02105505-komondor/n02105505_4260.jpg, saved cropped images: ['./data/Cropped Images/n02105505-komondor/cropped_0_n02105505_4260.jpg']
# Processed ./data/Images/n02105505-komondor/n02105505_4248.jpg, saved cropped images: ['./data/Cropped Images/n02105505-komondor/cropped_0_n02105505_4248.jpg']
# Processed ./data/Images/n02105505-komondor/n02105505_4076.jpg, saved cropped images: ['./data/Cropped Images/n02105505-komondor/cropped_0_n02105505_4076.jpg']
# Processed ./data/Images/n02105505-komondor/n02105505_3679.jpg, saved cropped images: ['./data/Cropped Images/n02105505-komondor/cropped_0_n02105505_3679.jpg']
# Processed ./data/Images/n02105505-komondor/n02105505_2942.jpg, saved cropped images: ['./data/Cropped Images/n02105505-komondor/cropped_0_n02105505_2942.jpg']
# Processed ./data/Images/n02105505-komondor/n02105505_1293.jpg, saved cropped images: ['./data/Cropped Images/n02105505-komondor/cropped_0_n02105505_1293.jpg']
# Processed ./data/Images/n02093256-Staffordshire_bullterrier/n02093256_14608.jpg, saved cropped images: ['./data/Cropped Images/n02093256-Staffordshire_bullterrier/cropped_0_n02093256_14608.jpg']
# Processed ./data/Images/n02093256-Staffordshire_bullterrier/n02093256_2817.jpg, saved cropped images: ['./data/Cropped Images/n02093256-Staffordshire_bullterrier/cropped_0_n02093256_2817.jpg']
# Processed ./data/Images/n02093256-Staffordshire_bullterrier/n02093256_14807.jpg, saved cropped images: ['./data/Cropped Images/n02093256-Staffordshire_bullterrier/cropped_0_n02093256_14807.jpg']
# Processed ./data/Images/n02093256-Staffordshire_bullterrier/n02093256_5943.jpg, saved cropped images: ['./data/Cropped Images/n02093256-Staffordshire_bullterrier/cropped_0_n02093256_5943.jpg']
# Processed ./data/Images/n02093256-Staffordshire_bullterrier/n02093256_11836.jpg, saved cropped images: ['./data/Cropped Images/n02093256-Staffordshire_bullterrier/cropped_0_n02093256_11836.jpg']
# Processed ./data/Images/n02093256-Staffordshire_bullterrier/n02093256_4452.jpg, saved cropped images: ['./data/Cropped Images/n02093256-Staffordshire_bullterrier/cropped_0_n02093256_4452.jpg']
# Processed ./data/Images/n02093256-Staffordshire_bullterrier/n02093256_4888.jpg, saved cropped images: ['./data/Cropped Images/n02093256-Staffordshire_bullterrier/cropped_0_n02093256_4888.jpg']
# Processed ./data/Images/n02093256-Staffordshire_bullterrier/n02093256_4678.jpg, saved cropped images: ['./data/Cropped Images/n02093256-Staffordshire_bullterrier/cropped_0_n02093256_4678.jpg']
# Processed ./data/Images/n02093256-Staffordshire_bullterrier/n02093256_7577.jpg, saved cropped images: ['./data/Cropped Images/n02093256-Staffordshire_bullterrier/cropped_0_n02093256_7577.jpg']
# Processed ./data/Images/n02093256-Staffordshire_bullterrier/n02093256_1489.jpg, saved cropped images: ['./data/Cropped Images/n02093256-Staffordshire_bullterrier/cropped_0_n02093256_1489.jpg']
# Processed ./data/Images/n02093256-Staffordshire_bullterrier/n02093256_8691.jpg, saved cropped images: ['./data/Cropped Images/n02093256-Staffordshire_bullterrier/cropped_0_n02093256_8691.jpg']
# Processed ./data/Images/n02093256-Staffordshire_bullterrier/n02093256_1272.jpg, saved cropped images: ['./data/Cropped Images/n02093256-Staffordshire_bullterrier/cropped_0_n02093256_1272.jpg']
# Processed ./data/Images/n02093256-Staffordshire_bullterrier/n02093256_11820.jpg, saved cropped images: ['./data/Cropped Images/n02093256-Staffordshire_bullterrier/cropped_0_n02093256_11820.jpg']
# Processed ./data/Images/n02093256-Staffordshire_bullterrier/n02093256_7830.jpg, saved cropped images: ['./data/Cropped Images/n02093256-Staffordshire_bullterrier/cropped_0_n02093256_7830.jpg']
# Processed ./data/Images/n02093256-Staffordshire_bullterrier/n02093256_2975.jpg, saved cropped images: ['./data/Cropped Images/n02093256-Staffordshire_bullterrier/cropped_0_n02093256_2975.jpg']
# Processed ./data/Images/n02093256-Staffordshire_bullterrier/n02093256_4874.jpg, saved cropped images: ['./data/Cropped Images/n02093256-Staffordshire_bullterrier/cropped_0_n02093256_4874.jpg']
# Processed ./data/Images/n02093256-Staffordshire_bullterrier/n02093256_5439.jpg, saved cropped images: ['./data/Cropped Images/n02093256-Staffordshire_bullterrier/cropped_0_n02093256_5439.jpg']
# Processed ./data/Images/n02093256-Staffordshire_bullterrier/n02093256_5820.jpg, saved cropped images: ['./data/Cropped Images/n02093256-Staffordshire_bullterrier/cropped_0_n02093256_5820.jpg']
# Processed ./data/Images/n02093256-Staffordshire_bullterrier/n02093256_5808.jpg, saved cropped images: ['./data/Cropped Images/n02093256-Staffordshire_bullterrier/cropped_0_n02093256_5808.jpg']
# Processed ./data/Images/n02093256-Staffordshire_bullterrier/n02093256_1854.jpg, saved cropped images: ['./data/Cropped Images/n02093256-Staffordshire_bullterrier/cropped_0_n02093256_1854.jpg']
# Processed ./data/Images/n02093256-Staffordshire_bullterrier/n02093256_10078.jpg, saved cropped images: ['./data/Cropped Images/n02093256-Staffordshire_bullterrier/cropped_0_n02093256_10078.jpg']
# Processed ./data/Images/n02093256-Staffordshire_bullterrier/n02093256_1505.jpg, saved cropped images: ['./data/Cropped Images/n02093256-Staffordshire_bullterrier/cropped_0_n02093256_1505.jpg']
# Processed ./data/Images/n02093256-Staffordshire_bullterrier/n02093256_3306.jpg, saved cropped images: ['./data/Cropped Images/n02093256-Staffordshire_bullterrier/cropped_0_n02093256_3306.jpg']
# Processed ./data/Images/n02093256-Staffordshire_bullterrier/n02093256_264.jpg, saved cropped images: ['./data/Cropped Images/n02093256-Staffordshire_bullterrier/cropped_0_n02093256_264.jpg', './data/Cropped Images/n02093256-Staffordshire_bullterrier/cropped_1_n02093256_264.jpg']
# Processed ./data/Images/n02093256-Staffordshire_bullterrier/n02093256_2780.jpg, saved cropped images: ['./data/Cropped Images/n02093256-Staffordshire_bullterrier/cropped_0_n02093256_2780.jpg']
# Processed ./data/Images/n02093256-Staffordshire_bullterrier/n02093256_2353.jpg, saved cropped images: ['./data/Cropped Images/n02093256-Staffordshire_bullterrier/cropped_0_n02093256_2353.jpg']
# Processed ./data/Images/n02093256-Staffordshire_bullterrier/n02093256_5428.jpg, saved cropped images: ['./data/Cropped Images/n02093256-Staffordshire_bullterrier/cropped_0_n02093256_5428.jpg']
# Processed ./data/Images/n02093256-Staffordshire_bullterrier/n02093256_3529.jpg, saved cropped images: ['./data/Cropped Images/n02093256-Staffordshire_bullterrier/cropped_0_n02093256_3529.jpg']
# Processed ./data/Images/n02093256-Staffordshire_bullterrier/n02093256_5600.jpg, saved cropped images: ['./data/Cropped Images/n02093256-Staffordshire_bullterrier/cropped_0_n02093256_5600.jpg']
# Processed ./data/Images/n02093256-Staffordshire_bullterrier/n02093256_2557.jpg, saved cropped images: ['./data/Cropped Images/n02093256-Staffordshire_bullterrier/cropped_0_n02093256_2557.jpg']
# Processed ./data/Images/n02093256-Staffordshire_bullterrier/n02093256_3113.jpg, saved cropped images: ['./data/Cropped Images/n02093256-Staffordshire_bullterrier/cropped_0_n02093256_3113.jpg']
# Processed ./data/Images/n02093256-Staffordshire_bullterrier/n02093256_1923.jpg, saved cropped images: ['./data/Cropped Images/n02093256-Staffordshire_bullterrier/cropped_0_n02093256_1923.jpg']
# Processed ./data/Images/n02093256-Staffordshire_bullterrier/n02093256_272.jpg, saved cropped images: ['./data/Cropped Images/n02093256-Staffordshire_bullterrier/cropped_0_n02093256_272.jpg']
# Processed ./data/Images/n02093256-Staffordshire_bullterrier/n02093256_5007.jpg, saved cropped images: ['./data/Cropped Images/n02093256-Staffordshire_bullterrier/cropped_0_n02093256_5007.jpg']
# Processed ./data/Images/n02093256-Staffordshire_bullterrier/n02093256_3462.jpg, saved cropped images: ['./data/Cropped Images/n02093256-Staffordshire_bullterrier/cropped_0_n02093256_3462.jpg']
# Processed ./data/Images/n02093256-Staffordshire_bullterrier/n02093256_1275.jpg, saved cropped images: ['./data/Cropped Images/n02093256-Staffordshire_bullterrier/cropped_0_n02093256_1275.jpg']
# Processed ./data/Images/n02093256-Staffordshire_bullterrier/n02093256_2542.jpg, saved cropped images: ['./data/Cropped Images/n02093256-Staffordshire_bullterrier/cropped_0_n02093256_2542.jpg']
# Processed ./data/Images/n02093256-Staffordshire_bullterrier/n02093256_4090.jpg, saved cropped images: ['./data/Cropped Images/n02093256-Staffordshire_bullterrier/cropped_0_n02093256_4090.jpg']
# Processed ./data/Images/n02093256-Staffordshire_bullterrier/n02093256_4245.jpg, saved cropped images: ['./data/Cropped Images/n02093256-Staffordshire_bullterrier/cropped_0_n02093256_4245.jpg']
# Processed ./data/Images/n02093256-Staffordshire_bullterrier/n02093256_1602.jpg, saved cropped images: ['./data/Cropped Images/n02093256-Staffordshire_bullterrier/cropped_0_n02093256_1602.jpg']
# Processed ./data/Images/n02093256-Staffordshire_bullterrier/n02093256_836.jpg, saved cropped images: ['./data/Cropped Images/n02093256-Staffordshire_bullterrier/cropped_0_n02093256_836.jpg']
# Processed ./data/Images/n02093256-Staffordshire_bullterrier/n02093256_759.jpg, saved cropped images: ['./data/Cropped Images/n02093256-Staffordshire_bullterrier/cropped_0_n02093256_759.jpg']
# Processed ./data/Images/n02093256-Staffordshire_bullterrier/n02093256_567.jpg, saved cropped images: ['./data/Cropped Images/n02093256-Staffordshire_bullterrier/cropped_0_n02093256_567.jpg']
# Processed ./data/Images/n02093256-Staffordshire_bullterrier/n02093256_1549.jpg, saved cropped images: ['./data/Cropped Images/n02093256-Staffordshire_bullterrier/cropped_0_n02093256_1549.jpg']
# Processed ./data/Images/n02093256-Staffordshire_bullterrier/n02093256_12347.jpg, saved cropped images: ['./data/Cropped Images/n02093256-Staffordshire_bullterrier/cropped_0_n02093256_12347.jpg']
# Processed ./data/Images/n02093256-Staffordshire_bullterrier/n02093256_13267.jpg, saved cropped images: ['./data/Cropped Images/n02093256-Staffordshire_bullterrier/cropped_0_n02093256_13267.jpg']
# Processed ./data/Images/n02093256-Staffordshire_bullterrier/n02093256_3941.jpg, saved cropped images: ['./data/Cropped Images/n02093256-Staffordshire_bullterrier/cropped_0_n02093256_3941.jpg']
# Processed ./data/Images/n02093256-Staffordshire_bullterrier/n02093256_3799.jpg, saved cropped images: ['./data/Cropped Images/n02093256-Staffordshire_bullterrier/cropped_0_n02093256_3799.jpg']
# Processed ./data/Images/n02093256-Staffordshire_bullterrier/n02093256_1371.jpg, saved cropped images: ['./data/Cropped Images/n02093256-Staffordshire_bullterrier/cropped_0_n02093256_1371.jpg']
# Processed ./data/Images/n02093256-Staffordshire_bullterrier/n02093256_2678.jpg, saved cropped images: ['./data/Cropped Images/n02093256-Staffordshire_bullterrier/cropped_0_n02093256_2678.jpg']
# Processed ./data/Images/n02093256-Staffordshire_bullterrier/n02093256_3994.jpg, saved cropped images: ['./data/Cropped Images/n02093256-Staffordshire_bullterrier/cropped_0_n02093256_3994.jpg']
# Processed ./data/Images/n02093256-Staffordshire_bullterrier/n02093256_1826.jpg, saved cropped images: ['./data/Cropped Images/n02093256-Staffordshire_bullterrier/cropped_0_n02093256_1826.jpg', './data/Cropped Images/n02093256-Staffordshire_bullterrier/cropped_1_n02093256_1826.jpg']
# Processed ./data/Images/n02093256-Staffordshire_bullterrier/n02093256_14522.jpg, saved cropped images: ['./data/Cropped Images/n02093256-Staffordshire_bullterrier/cropped_0_n02093256_14522.jpg']
# Processed ./data/Images/n02093256-Staffordshire_bullterrier/n02093256_5711.jpg, saved cropped images: ['./data/Cropped Images/n02093256-Staffordshire_bullterrier/cropped_0_n02093256_5711.jpg']
# Processed ./data/Images/n02093256-Staffordshire_bullterrier/n02093256_5936.jpg, saved cropped images: ['./data/Cropped Images/n02093256-Staffordshire_bullterrier/cropped_0_n02093256_5936.jpg']
# Processed ./data/Images/n02093256-Staffordshire_bullterrier/n02093256_4022.jpg, saved cropped images: ['./data/Cropped Images/n02093256-Staffordshire_bullterrier/cropped_0_n02093256_4022.jpg']
# Processed ./data/Images/n02093256-Staffordshire_bullterrier/n02093256_4036.jpg, saved cropped images: ['./data/Cropped Images/n02093256-Staffordshire_bullterrier/cropped_0_n02093256_4036.jpg']
# Processed ./data/Images/n02093256-Staffordshire_bullterrier/n02093256_367.jpg, saved cropped images: ['./data/Cropped Images/n02093256-Staffordshire_bullterrier/cropped_0_n02093256_367.jpg']
# Processed ./data/Images/n02093256-Staffordshire_bullterrier/n02093256_1638.jpg, saved cropped images: ['./data/Cropped Images/n02093256-Staffordshire_bullterrier/cropped_0_n02093256_1638.jpg']
# Processed ./data/Images/n02093256-Staffordshire_bullterrier/n02093256_3614.jpg, saved cropped images: ['./data/Cropped Images/n02093256-Staffordshire_bullterrier/cropped_0_n02093256_3614.jpg']
# Processed ./data/Images/n02093256-Staffordshire_bullterrier/n02093256_4972.jpg, saved cropped images: ['./data/Cropped Images/n02093256-Staffordshire_bullterrier/cropped_0_n02093256_4972.jpg']
# Processed ./data/Images/n02093256-Staffordshire_bullterrier/n02093256_6397.jpg, saved cropped images: ['./data/Cropped Images/n02093256-Staffordshire_bullterrier/cropped_0_n02093256_6397.jpg']
# Processed ./data/Images/n02093256-Staffordshire_bullterrier/n02093256_5139.jpg, saved cropped images: ['./data/Cropped Images/n02093256-Staffordshire_bullterrier/cropped_0_n02093256_5139.jpg']
# Processed ./data/Images/n02093256-Staffordshire_bullterrier/n02093256_8623.jpg, saved cropped images: ['./data/Cropped Images/n02093256-Staffordshire_bullterrier/cropped_0_n02093256_8623.jpg']
# Processed ./data/Images/n02093256-Staffordshire_bullterrier/n02093256_3762.jpg, saved cropped images: ['./data/Cropped Images/n02093256-Staffordshire_bullterrier/cropped_0_n02093256_3762.jpg']
# Processed ./data/Images/n02093256-Staffordshire_bullterrier/n02093256_6008.jpg, saved cropped images: ['./data/Cropped Images/n02093256-Staffordshire_bullterrier/cropped_0_n02093256_6008.jpg']
# Processed ./data/Images/n02093256-Staffordshire_bullterrier/n02093256_774.jpg, saved cropped images: ['./data/Cropped Images/n02093256-Staffordshire_bullterrier/cropped_0_n02093256_774.jpg']
# Processed ./data/Images/n02093256-Staffordshire_bullterrier/n02093256_8541.jpg, saved cropped images: ['./data/Cropped Images/n02093256-Staffordshire_bullterrier/cropped_0_n02093256_8541.jpg']
# Processed ./data/Images/n02093256-Staffordshire_bullterrier/n02093256_14914.jpg, saved cropped images: ['./data/Cropped Images/n02093256-Staffordshire_bullterrier/cropped_0_n02093256_14914.jpg']
# Processed ./data/Images/n02093256-Staffordshire_bullterrier/n02093256_2737.jpg, saved cropped images: ['./data/Cropped Images/n02093256-Staffordshire_bullterrier/cropped_0_n02093256_2737.jpg']
# Processed ./data/Images/n02093256-Staffordshire_bullterrier/n02093256_12785.jpg, saved cropped images: ['./data/Cropped Images/n02093256-Staffordshire_bullterrier/cropped_0_n02093256_12785.jpg']
# Processed ./data/Images/n02093256-Staffordshire_bullterrier/n02093256_417.jpg, saved cropped images: ['./data/Cropped Images/n02093256-Staffordshire_bullterrier/cropped_0_n02093256_417.jpg']
# Processed ./data/Images/n02093256-Staffordshire_bullterrier/n02093256_5110.jpg, saved cropped images: ['./data/Cropped Images/n02093256-Staffordshire_bullterrier/cropped_0_n02093256_5110.jpg']
# Processed ./data/Images/n02093256-Staffordshire_bullterrier/n02093256_7075.jpg, saved cropped images: ['./data/Cropped Images/n02093256-Staffordshire_bullterrier/cropped_0_n02093256_7075.jpg']
# Processed ./data/Images/n02093256-Staffordshire_bullterrier/n02093256_5647.jpg, saved cropped images: ['./data/Cropped Images/n02093256-Staffordshire_bullterrier/cropped_0_n02093256_5647.jpg']
# Processed ./data/Images/n02093256-Staffordshire_bullterrier/n02093256_11732.jpg, saved cropped images: ['./data/Cropped Images/n02093256-Staffordshire_bullterrier/cropped_0_n02093256_11732.jpg', './data/Cropped Images/n02093256-Staffordshire_bullterrier/cropped_1_n02093256_11732.jpg']
# Processed ./data/Images/n02093256-Staffordshire_bullterrier/n02093256_1384.jpg, saved cropped images: ['./data/Cropped Images/n02093256-Staffordshire_bullterrier/cropped_0_n02093256_1384.jpg']
# Processed ./data/Images/n02093256-Staffordshire_bullterrier/n02093256_13858.jpg, saved cropped images: ['./data/Cropped Images/n02093256-Staffordshire_bullterrier/cropped_0_n02093256_13858.jpg']
# Processed ./data/Images/n02093256-Staffordshire_bullterrier/n02093256_4997.jpg, saved cropped images: ['./data/Cropped Images/n02093256-Staffordshire_bullterrier/cropped_0_n02093256_4997.jpg', './data/Cropped Images/n02093256-Staffordshire_bullterrier/cropped_1_n02093256_4997.jpg']
# Processed ./data/Images/n02093256-Staffordshire_bullterrier/n02093256_6158.jpg, saved cropped images: ['./data/Cropped Images/n02093256-Staffordshire_bullterrier/cropped_0_n02093256_6158.jpg', './data/Cropped Images/n02093256-Staffordshire_bullterrier/cropped_1_n02093256_6158.jpg', './data/Cropped Images/n02093256-Staffordshire_bullterrier/cropped_2_n02093256_6158.jpg']
# Processed ./data/Images/n02093256-Staffordshire_bullterrier/n02093256_1757.jpg, saved cropped images: ['./data/Cropped Images/n02093256-Staffordshire_bullterrier/cropped_0_n02093256_1757.jpg']
# Processed ./data/Images/n02093256-Staffordshire_bullterrier/n02093256_7454.jpg, saved cropped images: ['./data/Cropped Images/n02093256-Staffordshire_bullterrier/cropped_0_n02093256_7454.jpg']
# Processed ./data/Images/n02093256-Staffordshire_bullterrier/n02093256_6992.jpg, saved cropped images: ['./data/Cropped Images/n02093256-Staffordshire_bullterrier/cropped_0_n02093256_6992.jpg']
# Processed ./data/Images/n02093256-Staffordshire_bullterrier/n02093256_5733.jpg, saved cropped images: ['./data/Cropped Images/n02093256-Staffordshire_bullterrier/cropped_0_n02093256_5733.jpg']
# Processed ./data/Images/n02093256-Staffordshire_bullterrier/n02093256_6575.jpg, saved cropped images: ['./data/Cropped Images/n02093256-Staffordshire_bullterrier/cropped_0_n02093256_6575.jpg']
# Processed ./data/Images/n02093256-Staffordshire_bullterrier/n02093256_5295.jpg, saved cropped images: ['./data/Cropped Images/n02093256-Staffordshire_bullterrier/cropped_0_n02093256_5295.jpg']
# Processed ./data/Images/n02093256-Staffordshire_bullterrier/n02093256_5134.jpg, saved cropped images: ['./data/Cropped Images/n02093256-Staffordshire_bullterrier/cropped_0_n02093256_5134.jpg']
# Processed ./data/Images/n02093256-Staffordshire_bullterrier/n02093256_5646.jpg, saved cropped images: ['./data/Cropped Images/n02093256-Staffordshire_bullterrier/cropped_0_n02093256_5646.jpg']
# Processed ./data/Images/n02093256-Staffordshire_bullterrier/n02093256_2513.jpg, saved cropped images: ['./data/Cropped Images/n02093256-Staffordshire_bullterrier/cropped_0_n02093256_2513.jpg']
# Processed ./data/Images/n02093256-Staffordshire_bullterrier/n02093256_2711.jpg, saved cropped images: ['./data/Cropped Images/n02093256-Staffordshire_bullterrier/cropped_0_n02093256_2711.jpg']
# Processed ./data/Images/n02093256-Staffordshire_bullterrier/n02093256_4374.jpg, saved cropped images: ['./data/Cropped Images/n02093256-Staffordshire_bullterrier/cropped_0_n02093256_4374.jpg']
# Processed ./data/Images/n02093256-Staffordshire_bullterrier/n02093256_14933.jpg, saved cropped images: ['./data/Cropped Images/n02093256-Staffordshire_bullterrier/cropped_0_n02093256_14933.jpg']
# Processed ./data/Images/n02093256-Staffordshire_bullterrier/n02093256_626.jpg, saved cropped images: ['./data/Cropped Images/n02093256-Staffordshire_bullterrier/cropped_0_n02093256_626.jpg']
# Processed ./data/Images/n02093256-Staffordshire_bullterrier/n02093256_3595.jpg, saved cropped images: ['./data/Cropped Images/n02093256-Staffordshire_bullterrier/cropped_0_n02093256_3595.jpg']
# Processed ./data/Images/n02093256-Staffordshire_bullterrier/n02093256_4007.jpg, saved cropped images: ['./data/Cropped Images/n02093256-Staffordshire_bullterrier/cropped_0_n02093256_4007.jpg']
# Processed ./data/Images/n02093256-Staffordshire_bullterrier/n02093256_8615.jpg, saved cropped images: ['./data/Cropped Images/n02093256-Staffordshire_bullterrier/cropped_0_n02093256_8615.jpg']
# Processed ./data/Images/n02093256-Staffordshire_bullterrier/n02093256_5325.jpg, saved cropped images: ['./data/Cropped Images/n02093256-Staffordshire_bullterrier/cropped_0_n02093256_5325.jpg']
# Processed ./data/Images/n02093256-Staffordshire_bullterrier/n02093256_1745.jpg, saved cropped images: ['./data/Cropped Images/n02093256-Staffordshire_bullterrier/cropped_0_n02093256_1745.jpg']
# Processed ./data/Images/n02093256-Staffordshire_bullterrier/n02093256_3378.jpg, saved cropped images: ['./data/Cropped Images/n02093256-Staffordshire_bullterrier/cropped_0_n02093256_3378.jpg']
# Processed ./data/Images/n02093256-Staffordshire_bullterrier/n02093256_8205.jpg, saved cropped images: ['./data/Cropped Images/n02093256-Staffordshire_bullterrier/cropped_0_n02093256_8205.jpg']
# Processed ./data/Images/n02093256-Staffordshire_bullterrier/n02093256_540.jpg, saved cropped images: ['./data/Cropped Images/n02093256-Staffordshire_bullterrier/cropped_0_n02093256_540.jpg']
# Processed ./data/Images/n02093256-Staffordshire_bullterrier/n02093256_5734.jpg, saved cropped images: ['./data/Cropped Images/n02093256-Staffordshire_bullterrier/cropped_0_n02093256_5734.jpg']
# Processed ./data/Images/n02093256-Staffordshire_bullterrier/n02093256_1546.jpg, saved cropped images: ['./data/Cropped Images/n02093256-Staffordshire_bullterrier/cropped_0_n02093256_1546.jpg']
# Processed ./data/Images/n02093256-Staffordshire_bullterrier/n02093256_2073.jpg, saved cropped images: ['./data/Cropped Images/n02093256-Staffordshire_bullterrier/cropped_0_n02093256_2073.jpg']
# Processed ./data/Images/n02093256-Staffordshire_bullterrier/n02093256_3190.jpg, saved cropped images: ['./data/Cropped Images/n02093256-Staffordshire_bullterrier/cropped_0_n02093256_3190.jpg']
# Processed ./data/Images/n02093256-Staffordshire_bullterrier/n02093256_3812.jpg, saved cropped images: ['./data/Cropped Images/n02093256-Staffordshire_bullterrier/cropped_0_n02093256_3812.jpg']
# Processed ./data/Images/n02093256-Staffordshire_bullterrier/n02093256_6177.jpg, saved cropped images: ['./data/Cropped Images/n02093256-Staffordshire_bullterrier/cropped_0_n02093256_6177.jpg']
# Processed ./data/Images/n02093256-Staffordshire_bullterrier/n02093256_5654.jpg, saved cropped images: ['./data/Cropped Images/n02093256-Staffordshire_bullterrier/cropped_0_n02093256_5654.jpg']
# Processed ./data/Images/n02093256-Staffordshire_bullterrier/n02093256_7043.jpg, saved cropped images: ['./data/Cropped Images/n02093256-Staffordshire_bullterrier/cropped_0_n02093256_7043.jpg']
# Processed ./data/Images/n02093256-Staffordshire_bullterrier/n02093256_3582.jpg, saved cropped images: ['./data/Cropped Images/n02093256-Staffordshire_bullterrier/cropped_0_n02093256_3582.jpg']
# Processed ./data/Images/n02093256-Staffordshire_bullterrier/n02093256_1183.jpg, saved cropped images: ['./data/Cropped Images/n02093256-Staffordshire_bullterrier/cropped_0_n02093256_1183.jpg']
# Processed ./data/Images/n02093256-Staffordshire_bullterrier/n02093256_12174.jpg, saved cropped images: ['./data/Cropped Images/n02093256-Staffordshire_bullterrier/cropped_0_n02093256_12174.jpg']
# Processed ./data/Images/n02093256-Staffordshire_bullterrier/n02093256_3353.jpg, saved cropped images: ['./data/Cropped Images/n02093256-Staffordshire_bullterrier/cropped_0_n02093256_3353.jpg']
# Processed ./data/Images/n02093256-Staffordshire_bullterrier/n02093256_225.jpg, saved cropped images: ['./data/Cropped Images/n02093256-Staffordshire_bullterrier/cropped_0_n02093256_225.jpg']
# Processed ./data/Images/n02093256-Staffordshire_bullterrier/n02093256_6969.jpg, saved cropped images: ['./data/Cropped Images/n02093256-Staffordshire_bullterrier/cropped_0_n02093256_6969.jpg']
# ...
# Processed ./data/Images/n02108089-boxer/n02108089_10939.jpg, saved cropped images: ['./data/Cropped Images/n02108089-boxer/cropped_0_n02108089_10939.jpg', './data/Cropped Images/n02108089-boxer/cropped_1_n02108089_10939.jpg']
# Processed ./data/Images/n02108089-boxer/n02108089_9076.jpg, saved cropped images: ['./data/Cropped Images/n02108089-boxer/cropped_0_n02108089_9076.jpg']
# Processed ./data/Images/n02108089-boxer/n02108089_2653.jpg, saved cropped images: ['./data/Cropped Images/n02108089-boxer/cropped_0_n02108089_2653.jpg']
# Processed ./data/Images/n02108089-boxer/n02108089_1560.jpg, saved cropped images: ['./data/Cropped Images/n02108089-boxer/cropped_0_n02108089_1560.jpg']
# Processed ./data/Images/n02108089-boxer/n02108089_1575.jpg, saved cropped images: ['./data/Cropped Images/n02108089-boxer/cropped_0_n02108089_1575.jpg']
# Processed ./data/Images/n02108089-boxer/n02108089_6583.jpg, saved cropped images: ['./data/Cropped Images/n02108089-boxer/cropped_0_n02108089_6583.jpg']
# Processed ./data/Images/n02108089-boxer/n02108089_522.jpg, saved cropped images: ['./data/Cropped Images/n02108089-boxer/cropped_0_n02108089_522.jpg']
# Processed ./data/Images/n02108089-boxer/n02108089_1159.jpg, saved cropped images: ['./data/Cropped Images/n02108089-boxer/cropped_0_n02108089_1159.jpg']
# Processed ./data/Images/n02108089-boxer/n02108089_3028.jpg, saved cropped images: ['./data/Cropped Images/n02108089-boxer/cropped_0_n02108089_3028.jpg']
# Processed ./data/Images/n02108089-boxer/n02108089_1367.jpg, saved cropped images: ['./data/Cropped Images/n02108089-boxer/cropped_0_n02108089_1367.jpg']
# Processed ./data/Images/n02108089-boxer/n02108089_6418.jpg, saved cropped images: ['./data/Cropped Images/n02108089-boxer/cropped_0_n02108089_6418.jpg']
# Processed ./data/Images/n02108089-boxer/n02108089_485.jpg, saved cropped images: ['./data/Cropped Images/n02108089-boxer/cropped_0_n02108089_485.jpg']
# Processed ./data/Images/n02108089-boxer/n02108089_122.jpg, saved cropped images: ['./data/Cropped Images/n02108089-boxer/cropped_0_n02108089_122.jpg']
# Processed ./data/Images/n02108089-boxer/n02108089_6008.jpg, saved cropped images: ['./data/Cropped Images/n02108089-boxer/cropped_0_n02108089_6008.jpg']
# Processed ./data/Images/n02108089-boxer/n02108089_268.jpg, saved cropped images: ['./data/Cropped Images/n02108089-boxer/cropped_0_n02108089_268.jpg']
# Processed ./data/Images/n02108089-boxer/n02108089_3400.jpg, saved cropped images: ['./data/Cropped Images/n02108089-boxer/cropped_0_n02108089_3400.jpg']
# Processed ./data/Images/n02108089-boxer/n02108089_1571.jpg, saved cropped images: ['./data/Cropped Images/n02108089-boxer/cropped_0_n02108089_1571.jpg']
# Processed ./data/Images/n02108089-boxer/n02108089_2723.jpg, saved cropped images: ['./data/Cropped Images/n02108089-boxer/cropped_0_n02108089_2723.jpg']
# Processed ./data/Images/n02108089-boxer/n02108089_6223.jpg, saved cropped images: ['./data/Cropped Images/n02108089-boxer/cropped_0_n02108089_6223.jpg', './data/Cropped Images/n02108089-boxer/cropped_1_n02108089_6223.jpg']
# Processed ./data/Images/n02108089-boxer/n02108089_5266.jpg, saved cropped images: ['./data/Cropped Images/n02108089-boxer/cropped_0_n02108089_5266.jpg']
# Processed ./data/Images/n02108089-boxer/n02108089_2482.jpg, saved cropped images: ['./data/Cropped Images/n02108089-boxer/cropped_0_n02108089_2482.jpg']
# Processed ./data/Images/n02108089-boxer/n02108089_1410.jpg, saved cropped images: ['./data/Cropped Images/n02108089-boxer/cropped_0_n02108089_1410.jpg']
# Processed ./data/Images/n02108089-boxer/n02108089_10901.jpg, saved cropped images: ['./data/Cropped Images/n02108089-boxer/cropped_0_n02108089_10901.jpg']
# Processed ./data/Images/n02108089-boxer/n02108089_15702.jpg, saved cropped images: ['./data/Cropped Images/n02108089-boxer/cropped_0_n02108089_15702.jpg']
# Processed ./data/Images/n02108089-boxer/n02108089_3365.jpg, saved cropped images: ['./data/Cropped Images/n02108089-boxer/cropped_0_n02108089_3365.jpg']
# Processed ./data/Images/n02108089-boxer/n02108089_530.jpg, saved cropped images: ['./data/Cropped Images/n02108089-boxer/cropped_0_n02108089_530.jpg']
# Processed ./data/Images/n02108089-boxer/n02108089_1003.jpg, saved cropped images: ['./data/Cropped Images/n02108089-boxer/cropped_0_n02108089_1003.jpg']
# Processed ./data/Images/n02108089-boxer/n02108089_11001.jpg, saved cropped images: ['./data/Cropped Images/n02108089-boxer/cropped_0_n02108089_11001.jpg']
# Processed ./data/Images/n02108089-boxer/n02108089_1956.jpg, saved cropped images: ['./data/Cropped Images/n02108089-boxer/cropped_0_n02108089_1956.jpg']
# Processed ./data/Images/n02108089-boxer/n02108089_849.jpg, saved cropped images: ['./data/Cropped Images/n02108089-boxer/cropped_0_n02108089_849.jpg']
# Processed ./data/Images/n02108089-boxer/n02108089_9724.jpg, saved cropped images: ['./data/Cropped Images/n02108089-boxer/cropped_0_n02108089_9724.jpg']
# Processed ./data/Images/n02108089-boxer/n02108089_3547.jpg, saved cropped images: ['./data/Cropped Images/n02108089-boxer/cropped_0_n02108089_3547.jpg']
# Processed ./data/Images/n02108089-boxer/n02108089_4002.jpg, saved cropped images: ['./data/Cropped Images/n02108089-boxer/cropped_0_n02108089_4002.jpg']
# Processed ./data/Images/n02108089-boxer/n02108089_7319.jpg, saved cropped images: ['./data/Cropped Images/n02108089-boxer/cropped_0_n02108089_7319.jpg']
# Processed ./data/Images/n02108089-boxer/n02108089_5043.jpg, saved cropped images: ['./data/Cropped Images/n02108089-boxer/cropped_0_n02108089_5043.jpg']
# Processed ./data/Images/n02108089-boxer/n02108089_7456.jpg, saved cropped images: ['./data/Cropped Images/n02108089-boxer/cropped_0_n02108089_7456.jpg']
# Processed ./data/Images/n02108089-boxer/n02108089_931.jpg, saved cropped images: ['./data/Cropped Images/n02108089-boxer/cropped_0_n02108089_931.jpg']
# Processed ./data/Images/n02108089-boxer/n02108089_2670.jpg, saved cropped images: ['./data/Cropped Images/n02108089-boxer/cropped_0_n02108089_2670.jpg']
# Processed ./data/Images/n02108089-boxer/n02108089_1353.jpg, saved cropped images: ['./data/Cropped Images/n02108089-boxer/cropped_0_n02108089_1353.jpg']
# Processed ./data/Images/n02108089-boxer/n02108089_3236.jpg, saved cropped images: ['./data/Cropped Images/n02108089-boxer/cropped_0_n02108089_3236.jpg']
# Processed ./data/Images/n02108089-boxer/n02108089_1031.jpg, saved cropped images: ['./data/Cropped Images/n02108089-boxer/cropped_0_n02108089_1031.jpg']
# Processed ./data/Images/n02108089-boxer/n02108089_1757.jpg, saved cropped images: ['./data/Cropped Images/n02108089-boxer/cropped_0_n02108089_1757.jpg']
# Processed ./data/Images/n02108089-boxer/n02108089_13340.jpg, saved cropped images: ['./data/Cropped Images/n02108089-boxer/cropped_0_n02108089_13340.jpg']
# Processed ./data/Images/n02108089-boxer/n02108089_12738.jpg, saved cropped images: ['./data/Cropped Images/n02108089-boxer/cropped_0_n02108089_12738.jpg']
# Processed ./data/Images/n02108089-boxer/n02108089_3395.jpg, saved cropped images: ['./data/Cropped Images/n02108089-boxer/cropped_0_n02108089_3395.jpg']
# Processed ./data/Images/n02108089-boxer/n02108089_12739.jpg, saved cropped images: ['./data/Cropped Images/n02108089-boxer/cropped_0_n02108089_12739.jpg']
# Processed ./data/Images/n02108089-boxer/n02108089_926.jpg, saved cropped images: ['./data/Cropped Images/n02108089-boxer/cropped_0_n02108089_926.jpg']
# Processed ./data/Images/n02108089-boxer/n02108089_8969.jpg, saved cropped images: ['./data/Cropped Images/n02108089-boxer/cropped_0_n02108089_8969.jpg']
# Processed ./data/Images/n02108089-boxer/n02108089_11032.jpg, saved cropped images: ['./data/Cropped Images/n02108089-boxer/cropped_0_n02108089_11032.jpg']
# Processed ./data/Images/n02108089-boxer/n02108089_11807.jpg, saved cropped images: ['./data/Cropped Images/n02108089-boxer/cropped_0_n02108089_11807.jpg', './data/Cropped Images/n02108089-boxer/cropped_1_n02108089_11807.jpg']
# Processed ./data/Images/n02108089-boxer/n02108089_6429.jpg, saved cropped images: ['./data/Cropped Images/n02108089-boxer/cropped_0_n02108089_6429.jpg']
# Processed ./data/Images/n02108089-boxer/n02108089_1418.jpg, saved cropped images: ['./data/Cropped Images/n02108089-boxer/cropped_0_n02108089_1418.jpg']
# Processed ./data/Images/n02108089-boxer/n02108089_117.jpg, saved cropped images: ['./data/Cropped Images/n02108089-boxer/cropped_0_n02108089_117.jpg']
# Processed ./data/Images/n02108089-boxer/n02108089_1626.jpg, saved cropped images: ['./data/Cropped Images/n02108089-boxer/cropped_0_n02108089_1626.jpg']
# Processed ./data/Images/n02108089-boxer/n02108089_922.jpg, saved cropped images: ['./data/Cropped Images/n02108089-boxer/cropped_0_n02108089_922.jpg']
# Processed ./data/Images/n02108089-boxer/n02108089_4158.jpg, saved cropped images: ['./data/Cropped Images/n02108089-boxer/cropped_0_n02108089_4158.jpg']
# Processed ./data/Images/n02108089-boxer/n02108089_9045.jpg, saved cropped images: ['./data/Cropped Images/n02108089-boxer/cropped_0_n02108089_9045.jpg']
# Processed ./data/Images/n02108089-boxer/n02108089_1357.jpg, saved cropped images: ['./data/Cropped Images/n02108089-boxer/cropped_0_n02108089_1357.jpg']
# Processed ./data/Images/n02108089-boxer/n02108089_1355.jpg, saved cropped images: ['./data/Cropped Images/n02108089-boxer/cropped_0_n02108089_1355.jpg']
# Processed ./data/Images/n02108089-boxer/n02108089_2106.jpg, saved cropped images: ['./data/Cropped Images/n02108089-boxer/cropped_0_n02108089_2106.jpg']
# Processed ./data/Images/n02108089-boxer/n02108089_1619.jpg, saved cropped images: ['./data/Cropped Images/n02108089-boxer/cropped_0_n02108089_1619.jpg']
# Processed ./data/Images/n02108089-boxer/n02108089_13839.jpg, saved cropped images: ['./data/Cropped Images/n02108089-boxer/cropped_0_n02108089_13839.jpg']
# Processed ./data/Images/n02108089-boxer/n02108089_11154.jpg, saved cropped images: ['./data/Cropped Images/n02108089-boxer/cropped_0_n02108089_11154.jpg']
# Processed ./data/Images/n02108089-boxer/n02108089_3557.jpg, saved cropped images: ['./data/Cropped Images/n02108089-boxer/cropped_0_n02108089_3557.jpg']
# Processed ./data/Images/n02108089-boxer/n02108089_13526.jpg, saved cropped images: ['./data/Cropped Images/n02108089-boxer/cropped_0_n02108089_13526.jpg']
# Processed ./data/Images/n02108089-boxer/n02108089_14659.jpg, saved cropped images: ['./data/Cropped Images/n02108089-boxer/cropped_0_n02108089_14659.jpg']
# Processed ./data/Images/n02108089-boxer/n02108089_5753.jpg, saved cropped images: ['./data/Cropped Images/n02108089-boxer/cropped_0_n02108089_5753.jpg']
# Processed ./data/Images/n02108089-boxer/n02108089_1859.jpg, saved cropped images: ['./data/Cropped Images/n02108089-boxer/cropped_0_n02108089_1859.jpg']
# Processed ./data/Images/n02108089-boxer/n02108089_15432.jpg, saved cropped images: ['./data/Cropped Images/n02108089-boxer/cropped_0_n02108089_15432.jpg']
# Processed ./data/Images/n02108089-boxer/n02108089_78.jpg, saved cropped images: ['./data/Cropped Images/n02108089-boxer/cropped_0_n02108089_78.jpg']
# Processed ./data/Images/n02108089-boxer/n02108089_10774.jpg, saved cropped images: ['./data/Cropped Images/n02108089-boxer/cropped_0_n02108089_10774.jpg']
# Processed ./data/Images/n02108089-boxer/n02108089_3269.jpg, saved cropped images: ['./data/Cropped Images/n02108089-boxer/cropped_0_n02108089_3269.jpg']
# Processed ./data/Images/n02108089-boxer/n02108089_9778.jpg, saved cropped images: ['./data/Cropped Images/n02108089-boxer/cropped_0_n02108089_9778.jpg']
# Processed ./data/Images/n02108089-boxer/n02108089_14074.jpg, saved cropped images: ['./data/Cropped Images/n02108089-boxer/cropped_0_n02108089_14074.jpg']
# Processed ./data/Images/n02108089-boxer/n02108089_4076.jpg, saved cropped images: ['./data/Cropped Images/n02108089-boxer/cropped_0_n02108089_4076.jpg']
# Processed ./data/Images/n02108089-boxer/n02108089_1654.jpg, saved cropped images: ['./data/Cropped Images/n02108089-boxer/cropped_0_n02108089_1654.jpg']
# Processed ./data/Images/n02108089-boxer/n02108089_5977.jpg, saved cropped images: ['./data/Cropped Images/n02108089-boxer/cropped_0_n02108089_5977.jpg']
# Processed ./data/Images/n02108089-boxer/n02108089_8739.jpg, saved cropped images: ['./data/Cropped Images/n02108089-boxer/cropped_0_n02108089_8739.jpg']
# Processed ./data/Images/n02108089-boxer/n02108089_1912.jpg, saved cropped images: ['./data/Cropped Images/n02108089-boxer/cropped_0_n02108089_1912.jpg']
# Processed ./data/Images/n02108089-boxer/n02108089_2360.jpg, saved cropped images: ['./data/Cropped Images/n02108089-boxer/cropped_0_n02108089_2360.jpg']
# Processed ./data/Images/n02108089-boxer/n02108089_1.jpg, saved cropped images: ['./data/Cropped Images/n02108089-boxer/cropped_0_n02108089_1.jpg']
# Processed ./data/Images/n02108089-boxer/n02108089_5423.jpg, saved cropped images: ['./data/Cropped Images/n02108089-boxer/cropped_0_n02108089_5423.jpg']
# Processed ./data/Images/n02108089-boxer/n02108089_2953.jpg, saved cropped images: ['./data/Cropped Images/n02108089-boxer/cropped_0_n02108089_2953.jpg']
# Processed ./data/Images/n02108089-boxer/n02108089_2007.jpg, saved cropped images: ['./data/Cropped Images/n02108089-boxer/cropped_0_n02108089_2007.jpg']
# Processed ./data/Images/n02108089-boxer/n02108089_3669.jpg, saved cropped images: ['./data/Cropped Images/n02108089-boxer/cropped_0_n02108089_3669.jpg']
# Processed ./data/Images/n02108089-boxer/n02108089_3899.jpg, saved cropped images: ['./data/Cropped Images/n02108089-boxer/cropped_0_n02108089_3899.jpg']
# Processed ./data/Images/n02108089-boxer/n02108089_11875.jpg, saved cropped images: ['./data/Cropped Images/n02108089-boxer/cropped_0_n02108089_11875.jpg']
# Processed ./data/Images/n02108089-boxer/n02108089_149.jpg, saved cropped images: ['./data/Cropped Images/n02108089-boxer/cropped_0_n02108089_149.jpg']
# Processed ./data/Images/n02108089-boxer/n02108089_11122.jpg, saved cropped images: ['./data/Cropped Images/n02108089-boxer/cropped_0_n02108089_11122.jpg']
# Processed ./data/Images/n02108089-boxer/n02108089_836.jpg, saved cropped images: ['./data/Cropped Images/n02108089-boxer/cropped_0_n02108089_836.jpg']
# Processed ./data/Images/n02108089-boxer/n02108089_11687.jpg, saved cropped images: ['./data/Cropped Images/n02108089-boxer/cropped_0_n02108089_11687.jpg']
# Processed ./data/Images/n02108089-boxer/n02108089_2367.jpg, saved cropped images: ['./data/Cropped Images/n02108089-boxer/cropped_0_n02108089_2367.jpg']
# Processed ./data/Images/n02108089-boxer/n02108089_995.jpg, saved cropped images: ['./data/Cropped Images/n02108089-boxer/cropped_0_n02108089_995.jpg']
# Processed ./data/Images/n02108089-boxer/n02108089_14112.jpg, saved cropped images: ['./data/Cropped Images/n02108089-boxer/cropped_0_n02108089_14112.jpg']
# Processed ./data/Images/n02108089-boxer/n02108089_7431.jpg, saved cropped images: ['./data/Cropped Images/n02108089-boxer/cropped_0_n02108089_7431.jpg']
# Processed ./data/Images/n02108089-boxer/n02108089_200.jpg, saved cropped images: ['./data/Cropped Images/n02108089-boxer/cropped_0_n02108089_200.jpg']
# Processed ./data/Images/n02108089-boxer/n02108089_13898.jpg, saved cropped images: ['./data/Cropped Images/n02108089-boxer/cropped_0_n02108089_13898.jpg']
# Processed ./data/Images/n02108089-boxer/n02108089_770.jpg, saved cropped images: ['./data/Cropped Images/n02108089-boxer/cropped_0_n02108089_770.jpg']
# Processed ./data/Images/n02108089-boxer/n02108089_10229.jpg, saved cropped images: ['./data/Cropped Images/n02108089-boxer/cropped_0_n02108089_10229.jpg']
# Processed ./data/Images/n02108089-boxer/n02108089_1690.jpg, saved cropped images: ['./data/Cropped Images/n02108089-boxer/cropped_0_n02108089_1690.jpg']
# Processed ./data/Images/n02108089-boxer/n02108089_12827.jpg, saved cropped images: ['./data/Cropped Images/n02108089-boxer/cropped_0_n02108089_12827.jpg']
# Processed ./data/Images/n02108089-boxer/n02108089_69.jpg, saved cropped images: ['./data/Cropped Images/n02108089-boxer/cropped_0_n02108089_69.jpg']
# Processed ./data/Images/n02108089-boxer/n02108089_2831.jpg, saved cropped images: ['./data/Cropped Images/n02108089-boxer/cropped_0_n02108089_2831.jpg']

# %% [markdown]
# ---

# %% [markdown]
# # Feature Extraction: Edge histogram AND Similarity Measurements

# %% [markdown]
# ## Imports

# %%
import matplotlib.pyplot as plt
from skimage import color, filters, exposure
from sklearn.metrics import pairwise_distances
import random
from sklearn import metrics

# %% [markdown]
# ## Load and Grayscale

# %%
def load_and_grayscale(image_path):
    image = io.imread(image_path)
    grayscaled_image = color.rgb2gray(image)
    # grayscaled_image = image
    return grayscaled_image

# %% [markdown]
# ## Angle Calculator

# %%
def angle(dx, dy):
    """Calculate the angles between horizontal and vertical operators."""
    return np.mod(np.arctan2(dy, dx), np.pi)

# %% [markdown]
# ## Angle of Gradients

# %%
def edge_angle(image):
    sobel_h = filters.sobel_h(image)
    sobel_v = filters.sobel_v(image)
    angle_sobel = angle(sobel_h, sobel_v)
    return angle_sobel

# %% [markdown]
# ## Edge Histograms

# %%
def compute_histogram(image_angle):
    hist, bin_centers = exposure.histogram(image_angle, nbins=36)
    return hist, bin_centers

# %% [markdown]
# ## Plotting Image and Histogram

# %%
def plotting(image, hist, bin_centers, title):
    fig, ax = plt.subplots(1, 2, figsize=(12, 4))
    ax[0].imshow(image, cmap='gray')
    ax[0].set_title(f'{title} - Grayscaled Image')

    ax[1].bar(bin_centers, hist, width=0.1)
    ax[1].set_title(f'{title} - Edge Histogram')
    ax[1].set_xlabel("Bins")
    ax[1].set_ylabel("Pixel Count")
    plt.show()

# %% [markdown]
# ## Distances Between Histograms

# %%
def compute_distances(hist1, hist2):
    hist1 = hist1.reshape(1, -1)
    hist2 = hist2.reshape(1, -1)
    
    euclidean = metrics.pairwise.euclidean_distances(hist1, hist2)
    manhattan = metrics.pairwise.manhattan_distances(hist1, hist2)
    cosine = metrics.pairwise.cosine_distances(hist1, hist2)
   
    return euclidean, manhattan, cosine

# %% [markdown]
# ## Breed names

# %%
def extract_breed_name(folder_name):
    breed_name = folder_name.split('-')[-1] 
    breed_name = breed_name.replace('_', ' ')
    return breed_name.title()

# %% [markdown]
# ## Run

# %%
main_folder = './data/Cropped Images'

folders = [f for f in os.listdir(main_folder) if os.path.isdir(os.path.join(main_folder, f))]

folder1, folder2, folder3, folder4 = [os.path.join(main_folder, folders[i]) for i in range(4)]

image1 = os.path.join(folder1, random.choice(os.listdir(folder1)))
image2 = os.path.join(folder2, random.choice(os.listdir(folder2)))
image3 = os.path.join(folder3, random.choice(os.listdir(folder3)))
image4 = os.path.join(folder4, random.choice(os.listdir(folder4)))

breed_name1 = extract_breed_name(os.path.basename(os.path.dirname(image1)))
breed_name2 = extract_breed_name(os.path.basename(os.path.dirname(image2)))
breed_name3 = extract_breed_name(os.path.basename(os.path.dirname(image3)))
breed_name4 = extract_breed_name(os.path.basename(os.path.dirname(image4)))

grayscaled_image1 = load_and_grayscale(image1)
grayscaled_image2 = load_and_grayscale(image2)
grayscaled_image3 = load_and_grayscale(image3)
grayscaled_image4 = load_and_grayscale(image4)

angle_sobel1 = edge_angle(grayscaled_image1)
angle_sobel2 = edge_angle(grayscaled_image2)
angle_sobel3 = edge_angle(grayscaled_image3)
angle_sobel4 = edge_angle(grayscaled_image4)

hist1, bin_centers1 = compute_histogram(angle_sobel1)
hist2, bin_centers2 = compute_histogram(angle_sobel2)
hist3, bin_centers3 = compute_histogram(angle_sobel3)
hist4, bin_centers4 = compute_histogram(angle_sobel4)

plotting(grayscaled_image1, hist1, bin_centers1, breed_name1)
plotting(grayscaled_image2, hist2, bin_centers2, breed_name2)
plotting(grayscaled_image3, hist3, bin_centers3, breed_name3)
plotting(grayscaled_image4, hist4, bin_centers4, breed_name4)

euclidean, manhattan, cosine = compute_distances(hist1, hist2)

print(f"Comparison of '{breed_name1}' and '{breed_name2}':")
print(f"Euclidean Distance: {euclidean}")
print(f"Manhattan Distance: {manhattan}")
print(f"Cosine Distance: {cosine}")
# Out:
# Comparison of 'Komondor' and 'Staffordshire Bullterrier':
# Euclidean Distance: [[663.68215284]]
# Manhattan Distance: [[3206.]]
# Cosine Distance: [[0.028805]]

# %% [markdown]
# ---

# %% [markdown]
# # Histogram of Oriented Gradient (HOG) feature descriptor

# %%
from skimage.feature import hog
from skimage import data

img = io.imread(image4)

fd, hog_image = hog(
    img,
    orientations=8,
    pixels_per_cell=(16, 16),
    cells_per_block=(1, 1),
    visualize=True,
    channel_axis=-1,
)

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(8, 4), sharex=True, sharey=True)

ax1.axis('off')
ax1.imshow(img, cmap=plt.cm.gray)
ax1.set_title('Input image')

# Rescale histogram for better display
hog_image_rescaled = exposure.rescale_intensity(hog_image, in_range=(0, 10))

ax2.axis('off')
ax2.imshow(hog_image_rescaled, cmap=plt.cm.gray)
ax2.set_title('Histogram of Oriented Gradients')
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# # Dimensionality reduction (using Principal Component Analysis, PCA)

# %% [markdown]
# ## Imports

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# ## All Images to Histograms

# %%
def all_to_histograms(image_files, histograms_folder):
    histograms_list = []
    labels = []
    
    for i, image_path in enumerate(image_files):

        class_label_full = os.path.basename(os.path.dirname(image_path))
        class_label = class_label_full.split('-')[1]
        labels.append(class_label.title())
        
        grayscaled_image = load_and_grayscale(image_path)
        angle_sobel = edge_angle(grayscaled_image)
        hist, bin_centers = compute_histogram(angle_sobel)

        histograms_list.append(hist)

    return histograms_list, labels

# %% [markdown]
# ## Principal Component Analysis (PCA)

# %%
images_folder = './data/Cropped Images/*/*'
histograms_folder = './data/Edge Histograms'
image_files = glob.glob(images_folder)

all_histograms, labels = all_to_histograms(image_files, histograms_folder)
histograms_array = np.array(all_histograms)

scaler = StandardScaler()
histograms_normalized = scaler.fit_transform(histograms_array)

unique_labels = np.unique(labels)
label_mapping = {label: i for i, label in enumerate(unique_labels)}
encoded_labels = np.array([label_mapping[label] for label in labels])

pca = PCA(n_components=2)
reduced_data = pca.fit_transform(histograms_normalized)

# %% [markdown]
# ## Plotting 2D Points

# %%
plt.figure(figsize=(8, 6))

for class_label, label_num in label_mapping.items():
    plt.scatter(reduced_data[encoded_labels == label_num, 0], 
                reduced_data[encoded_labels == label_num, 1], 
                label=f'Class {class_label}')

plt.xlabel('Component 1')
plt.ylabel('Component 2')
plt.legend()
plt.title('PCA-reduced Feature Visualization')
plt.show()
